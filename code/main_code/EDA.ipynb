# %%
import sys
sys.path.append('../component')
from class_EDA import EDA
from utils import *
import os
os.getcwd()
# Out:
# '/home/ubuntu/Capstone_Group_1/code/main_code'

# %%
# traffic.csv
eda = EDA('../data/traffic.csv')
df = eda.read_data()
eda.plots(df)
eda.stationarity(df)
# Out:
# ADF Statistic: -7.518278
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567
# Pass ADF test.
# Results of KPSS Test:
# p-value: 0.010000
# Test Statistic            15.671517
# p-value                    0.010000
# Lags Used                119.000000
# Critical Value (10%)       0.347000
# Critical Value (5%)        0.463000
# Critical Value (2.5%)      0.574000
# Critical Value (1%)        0.739000
# dtype: float64
# Fail to pass KPSS test.
# /home/ubuntu/Capstone_Group_1/code/main_code/../component/utils.py:73: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpsstest = kpss(timeseries, regression='c', nlags="auto")

# %%
df.head()
# Out:
#                  date  vehicles
# 0 2015-11-01 00:00:00        15
# 1 2015-11-01 01:00:00        13
# 2 2015-11-01 02:00:00        10
# 3 2015-11-01 03:00:00         7
# 4 2015-11-01 04:00:00         9

# %%
# weather.csv
eda = EDA('../data/weather.csv')
df = eda.read_data()
eda.plots(df)
eda.stationarity(df)
# Out:
# ADF Statistic: -12.701473
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567
# Pass ADF test.
# Results of KPSS Test:
# p-value: 0.010000
# Test Statistic             1.294409
# p-value                    0.010000
# Lags Used                191.000000
# Critical Value (10%)       0.347000
# Critical Value (5%)        0.463000
# Critical Value (2.5%)      0.574000
# Critical Value (1%)        0.739000
# dtype: float64
# Fail to pass KPSS test.
# /home/ubuntu/Capstone_Group_1/code/main_code/../component/utils.py:73: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpsstest = kpss(timeseries, regression='c', nlags="auto")

# %%
# weather.csv
eda = EDA('../data/power_consumption.csv')
df = eda.read_data()
eda.plots(df)
eda.stationarity(df)
# Out:
# ADF Statistic: -32.121279
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567
# Pass ADF test.
# Results of KPSS Test:
# p-value: 0.010000
# Test Statistic             6.0186
# p-value                    0.0100
# Lags Used                132.0000
# Critical Value (10%)       0.3470
# Critical Value (5%)        0.4630
# Critical Value (2.5%)      0.5740
# Critical Value (1%)        0.7390
# dtype: float64
# Fail to pass KPSS test.
# /home/ubuntu/Capstone_Group_1/code/main_code/../component/utils.py:73: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpsstest = kpss(timeseries, regression='c', nlags="auto")

# %%
# air_pollution.csv
eda = EDA('../data/air_pollution.csv')
df = eda.read_data()
eda.plots(df)
eda.stationarity(df)
