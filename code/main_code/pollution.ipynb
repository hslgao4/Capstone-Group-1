# %%
import sys
sys.path.append('../component')  # Ensure sys is imported before using it
import pandas as pd
from utils import *
from class_ARIMA_model import ARIMA_model
from class_EDA import *
import os
os.getcwd()
# Out:
# '/home/ubuntu/Capstone_Group_1/code/main_code'

# %%
path = '../data/air_pollution.csv'
eda = EDA(path)
df = eda.read_data()
eda.plots(df, 40, 24, Col=1)
# Out:
# The strength of trend for this data set is 86.01%
# The strength of seasonality for this data set is  40.67%

# %%
path = '../data/air_pollution.csv'
eda = EDA(path)
df = eda.read_data()
